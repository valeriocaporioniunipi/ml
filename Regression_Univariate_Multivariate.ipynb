# %%
from sklearn.datasets import load_wine
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
from sklearn.model_selection import train_test_split

# %%
d = load_wine(as_frame=True)
df = d["data"]
X = df.values
df.head()
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0    14.23        1.71  2.43               15.6      127.0           2.80
# 1    13.20        1.78  2.14               11.2      100.0           2.65
# 2    13.16        2.36  2.67               18.6      101.0           2.80
# 3    14.37        1.95  2.50               16.8      113.0           3.85
# 4    13.24        2.59  2.87               21.0      118.0           2.80
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    od280/od315_of_diluted_wines  proline
# 0                          3.92   1065.0
# 1                          3.40   1050.0
# 2                          3.17   1185.0
# 3                          3.45   1480.0
# 4                          2.93    735.0

# %%
df_train, df_test = train_test_split(df, test_size=0.3, random_state=100)

# %% [markdown]
# # Simple Regression

# %%
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from sklearn.linear_model import LinearRegression, Ridge, Lasso

# %%
x_train = df_train["flavanoids"].values.reshape(-1, 1)
y_train = df_train["od280/od315_of_diluted_wines"].values

x_test = df_test["flavanoids"].values.reshape(-1, 1)
y_test = df_test["od280/od315_of_diluted_wines"].values

# %% [markdown]
# ## Linear Regression

# %%
reg = LinearRegression()
reg.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
print('Coefficients: \n', reg.coef_)
print('Intercept: \n', reg.intercept_)
# Out:
# Coefficients:
#  [0.5197317]
# Intercept:
#  1.5724936793693256

# %%
sns.scatterplot(data=df_train, x="flavanoids", y="od280/od315_of_diluted_wines")
plt.plot(x_train, reg.coef_[0]*x_train+reg.intercept_, c="red")

# %%
y_pred = reg.predict(x_test) #manca per gli altri ma da fare

print('R2: %.3f' % r2_score(y_test, y_pred))
print('MSE: %.3f' % mean_squared_error(y_test, y_pred))
print('MAE: %.3f' % mean_absolute_error(y_test, y_pred))
# Out:
# R2: 0.656
# MSE: 0.182
# MAE: 0.335

# %%
sns.scatterplot(data=df_test, x="flavanoids", y="od280/od315_of_diluted_wines")
plt.plot(x_test, reg.coef_[0]*x_test+reg.intercept_, c="red")

# %% [markdown]
# ### Ridge

# %%
reg = Ridge()
reg.fit(x_train, y_train)
print('Coefficients: \n', reg.coef_)
print('Intercept: \n', reg.intercept_)
# Out:
# Coefficients:
#  [0.51548316]
# Intercept:
#  1.5817414559720187

# %%
sns.scatterplot(data=df_train, x="flavanoids", y="od280/od315_of_diluted_wines")
plt.plot(x_train, reg.coef_[0]*x_train+reg.intercept_, c="red")

# %% [markdown]
# ### Lasso

# %%
reg = Lasso()
reg.fit(x_train, y_train)
print('Coefficients: \n', reg.coef_)
print('Intercept: \n', reg.intercept_)
# Out:
# Coefficients:
#  [0.]
# Intercept:
#  2.7037903225806454

# %%
sns.scatterplot(data=df_train, x="flavanoids", y="od280/od315_of_diluted_wines")
plt.plot(x_train, reg.coef_[0]*x_train+reg.intercept_, c="red")

# %% [markdown]
# ## Nonlinear regression

# %% [markdown]
# ### Decision Tree Regressor

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
reg = DecisionTreeRegressor()

# %%
reg.fit(x_train, y_train)
# Out:
# DecisionTreeRegressor()

# %%
y_pred = reg.predict(x_test)
print('R2: %.3f' % r2_score(y_test, y_pred))
print('MSE: %.3f' % mean_squared_error(y_test, y_pred))
print('MAE: %.3f' % mean_absolute_error(y_test, y_pred))
# Out:
# R2: 0.546
# MSE: 0.240
# MAE: 0.374

# %%
sns.scatterplot(data=df_train, x="flavanoids", y="od280/od315_of_diluted_wines", label="True")
sns.scatterplot(data=df_train, x="flavanoids", y=reg.predict(x_train), label="Predicted", marker="X")
plt.legend()
plt.show()

# %% [markdown]
# ### KNN Regressor

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
reg = KNeighborsRegressor()

# %%
reg.fit(x_train, y_train)
# Out:
# KNeighborsRegressor()

# %%
y_pred = reg.predict(x_test)
print('R2: %.3f' % r2_score(y_test, y_pred))
print('MSE: %.3f' % mean_squared_error(y_test, y_pred))
print('MAE: %.3f' % mean_absolute_error(y_test, y_pred))
# Out:
# R2: 0.578
# MSE: 0.223
# MAE: 0.373

# %%
sns.scatterplot(data=df_train, x="flavanoids", y="od280/od315_of_diluted_wines", label="True")
sns.scatterplot(data=df_train, x="flavanoids", y=reg.predict(x_train), label="Predicted", marker="X")
plt.legend()
plt.show()

# %% [markdown]
# # Multiple Regression

# %%
X_train = df_train[["flavanoids", "proline"]].values
y_train = df_train["od280/od315_of_diluted_wines"].values

X_test = df_test[["flavanoids", "proline"]].values
y_test = df_test["od280/od315_of_diluted_wines"].values

# %% [markdown]
# ## Linear Regression

# %%
reg = LinearRegression()
reg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = reg.predict(X_test)
print('R2: %.3f' % r2_score(y_test, y_pred))
print('MSE: %.3f' % mean_squared_error(y_test, y_pred))
print('MAE: %.3f' % mean_absolute_error(y_test, y_pred))
# Out:
# R2: 0.625
# MSE: 0.198
# MAE: 0.345

# %%
sns.scatterplot(data=df_test, x="hue", y="od280/od315_of_diluted_wines", label="True")
sns.scatterplot(data=df_test, x="hue", y=reg.predict(X_test), label="Predicted", marker="X")
plt.legend()
plt.show()

# %% [markdown]
# ## Nonlinear Regression

# %%
reg = DecisionTreeRegressor()

# %%
reg.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor()

# %%
y_pred = reg.predict(X_test)
print('R2: %.3f' % r2_score(y_test, y_pred))
print('MSE: %.3f' % mean_squared_error(y_test, y_pred))
print('MAE: %.3f' % mean_absolute_error(y_test, y_pred))
# Out:
# R2: 0.444
# MSE: 0.294
# MAE: 0.400

# %%
sns.scatterplot(data=df_test, x="hue", y="od280/od315_of_diluted_wines", label="True")
sns.scatterplot(data=df_test, x="hue", y=reg.predict(X_test), label="Predicted", marker="X")
plt.legend()
plt.show()

# %% [markdown]
# # Multivariate Regression (2+ target variables)

# %%
X_train = df_train[["flavanoids", "proline"]].values
y_train = df_train[["od280/od315_of_diluted_wines", "ash"]].values

X_test = df_test[["flavanoids", "proline"]].values
y_test = df_test[["od280/od315_of_diluted_wines", "ash"]].values

# %%
reg = DecisionTreeRegressor()

# %%
reg.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor()

# %%
y_pred = reg.predict(X_test)
print('R2: %.3f' % r2_score(y_test, y_pred))
print('MSE: %.3f' % mean_squared_error(y_test, y_pred))
print('MAE: %.3f' % mean_absolute_error(y_test, y_pred))
# Out:
# R2: -0.024
# MSE: 0.214
# MAE: 0.336

# %%
y_pred = reg.predict(X_test)
y_pred
# Out:
# array([[2.57, 2.38],
#        [1.29, 2.36],
#        [3.58, 2.45],
#        [2.96, 1.7 ],
#        [1.67, 2.28],
#        [2.77, 1.9 ],
#        [3.64, 2.39],
#        [1.56, 2.6 ],
#        [2.01, 2.32],
#        [3.47, 2.41],
#        [1.55, 2.1 ],
#        [3.  , 2.29],
#        [1.82, 2.19],
#        [1.82, 2.19],
#        [1.56, 2.6 ],
#        [2.93, 2.68],
#        [1.73, 2.64],
#        [3.58, 2.45],
#        [1.42, 2.4 ],
#        [4.  , 2.36],
#        [2.01, 2.32],
#        [3.5 , 2.6 ],
#        [2.65, 2.42],
#        [1.59, 2.02],
#        [3.53, 2.51],
#        [3.33, 2.44],
#        [2.01, 2.32],
#        [3.13, 2.4 ],
#        [2.42, 2.28],
#        [1.51, 2.28],
#        [1.68, 2.3 ],
#        [1.93, 2.36],
#        [3.  , 2.7 ],
#        [3.13, 2.4 ],
#        [2.65, 2.42],
#        [1.59, 2.02],
#        [2.78, 2.3 ],
#        [2.44, 1.88],
#        [1.82, 2.19],
#        [1.82, 2.19],
#        [4.  , 2.36],
#        [2.65, 2.42],
#        [2.47, 2.35],
#        [1.58, 2.2 ],
#        [3.92, 2.43],
#        [1.51, 2.28],
#        [2.05, 2.35],
#        [2.11, 2.58],
#        [3.53, 2.51],
#        [2.65, 2.72],
#        [3.47, 2.41],
#        [3.12, 2.73],
#        [3.36, 2.56],
#        [1.69, 2.64]])

# %%
sns.scatterplot(data=df_test, x="hue", y="od280/od315_of_diluted_wines", label="True")
sns.scatterplot(data=df_test, x="hue", y=reg.predict(X_test)[:, 0], label="Predicted", marker="X")
plt.legend()
plt.show()

# %%
sns.scatterplot(data=df_test, x="hue", y="ash", label="True")
sns.scatterplot(data=df_test, x="hue", y=reg.predict(X_test)[:, 1], label="Predicted", marker="X")
plt.legend()
plt.show()

# %% [markdown]
# always experiment with the parameters and comment the different results

# %% [markdown]
# the imbd dataset with the values needs to be used JUST for regression

# %% [markdown]
# you can:
# 1) train the decision tree classifier
# 2) print the feature importance of the tree
# 3) see which they are and use just them in the linear model to see if indeed what is meant to be the most important feature for the regression decision tree is important also for the regression model
